# %%
import pandas as pd

df = pd.read_csv('/content/pokemon.csv')
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %% [markdown]
# **(1 point) Display pokedex number, English name, Japanese name, and hp values regarding all 1st-generation pokemons. The results must be ordered starting from the maximum hp to the minimum hp (for the same hp value, order by the pokedex number from small to large).**

# %%
df.loc[ df['generation'] == 1, ['pokedex_number','name','japanese_name', 'hp'] ].sort_values(by=['hp', 'pokedex_number'], ascending=[False, True])
# Out:
#      pokedex_number        name japanese_name   hp
# 112             113     Chansey     Luckyラッキー  250
# 142             143     Snorlax   Kabigonカビゴン  160
# 39               40  Wigglytuff   Pukurinプクリン  140
# 130             131      Lapras   Laplaceラプラス  130
# 133             134    Vaporeon  Showersシャワーズ  130
# ..              ...         ...           ...  ...
# 139             140      Kabuto     Kabutoカブト   30
# 62               63        Abra     Caseyケーシィ   25
# 80               81   Magnemite       Coilコイル   25
# 128             129    Magikarp  Koikingコイキング   20
# 49               50     Diglett     Digdaディグダ   10
#
# [151 rows x 4 columns]

# %% [markdown]
# **(1 point) How many pokemons that both type1 and type2 are not NA, and have type1 of either water or grass?**

# %%
#isin(['water', 'grass']) already ensures that type1 is not NA. Removed df['type1'].notna()

filtered_df = df.loc[df['type1'].isin(['water', 'grass']) & df['type2'].notna()]

count = filtered_df.shape[0]
count
# Out:
# 94

# %% [markdown]
# **(1.5 points) Display pokedex number, English name, hp, abilities, and capture rate values regarding all pokemons whose abilities attribute includes 'super luck' and whose capture rate is greater than 90.**

# %%
df['capture_rate'] = pd.to_numeric(df['capture_rate'], errors='coerce')

df.loc[(df['abilities'].str.contains('super luck', case=False)) & (df['capture_rate'] > 90), ['pokedex_number', 'name', 'hp', 'abilities', 'capture_rate']]
# Out:
#      pokedex_number       name  hp                                 abilities  \
# 174             175     Togepi  35  ['Hustle', 'Serene Grace', 'Super Luck']
# 518             519     Pidove  50    ['Big Pecks', 'Super Luck', 'Rivalry']
# 519             520  Tranquill  62    ['Big Pecks', 'Super Luck', 'Rivalry']
#
#      capture_rate
# 174         190.0
# 518         255.0
# 519         120.0
